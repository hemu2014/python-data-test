# %% [markdown]
# <a href="https://colab.research.google.com/github/hemu2014/python-data-test/blob/main/db-test--33/lesson-11-reading-data-from-relational-databases/files/Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##json读取补充

# %%
import numpy as np
import pandas as pd

artists = pd.read_json('artists.json')
artists.head()
#artists.drop(['bio'], axis='columns', inplace=True)

#artists.set_index('name', inplace=True)

#artists.to_csv('artists.csv')
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
artists.drop(['bio'],inplace=True,axis=1)  # inplace原地修改， axis为1表示为列

# %%
artists.head(3)
# Out:
#                  name        years                         genre nationality
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican

# %%
artists.set_index('name', inplace=True)

# %%
artists.head(3)
# Out:
#                           years                         genre nationality
# name
# Amedeo Modigliani   1884 - 1920                 Expressionism     Italian
# Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# Diego Rivera        1886 - 1957       Social Realism,Muralism     Mexican

# %%
artists.to_csv('artists.csv')

# %% [markdown]
# ###test语句

# %%
artists.iloc[3]['genre']
# Out:
# 'Impressionism'

# %% [markdown]
# ###equals（）---判断行索引是否一致

# %%
i = pd.Index(['Amedeo Modigliani', 'Vasiliy Kandinskiy', 'Diego Rivera',
              'Claude Monet', 'Rene Magritte'])
artists.index.equals(i)
# Out:
# True

# %%
artists.shape
# Out:
# (5, 3)

# %%
def test_artists():
    assert artists.iloc[3]['genre'] == 'Impressionism'
def test_index():
    i = pd.Index(['Amedeo Modigliani', 'Vasiliy Kandinskiy', 'Diego Rivera',
              'Claude Monet', 'Rene Magritte'])

    assert artists.index.equals(i)
def test_shape():
    assert artists.shape == (5, 3)

# %% [markdown]
# .rmotr文件

# %%
uuid = "d3abb823-ec33-4109-aa6c-ced48f410a3f"
name = "Reading Data with Python and Pandas"

# %%
import numpy as np
import pandas as pd
import json
from pandas import json_normalize

with open('artists.json') as file:
    json_dict = json.load(file)

artists = json_normalize(json_dict)

biography = json_normalize(json_dict,
                           record_path='bio',
                           meta=['name'])   # 指定bio列解析，追加name列

# %%
artists
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
biography
# Out:
#                                            full name  \
# 0                         Amedeo Clemente Modigliani
# 1                     Wassily Wassilyevich Kandinsky
# 2  Diego María de la Concepción Juan Nepomuceno E...
# 3                                 Oscar-Claude Monet
# 4                    René François Ghislain Magritte
#
#                                        pronunciation  \
# 0                             [ameˈdɛːo modiʎˈʎaːni]
# 1  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# 2                                   [ˈdjeɣo riˈβeɾa]
# 3                                        [klod mɔnɛ]
# 4                        [ʁəne fʁɑ̃swa ɡilɛ̃ maɡʁit]
#
#                                            life span  \
# 0                     12 July 1884 – 24 January 1920
# 1  16 December [O.S. 4 December] 1866 – 13 Decemb...
# 2               December 8, 1886 – November 24, 1957
# 3                 14 November 1840 – 5 December 1926
# 4                  21 November 1898 – 15 August 1967
#
#                                                 info  \
# 0  was an Italian Jewish painter and sculptor who...
# 1            was a Russian painter and art theorist.
# 2  was a prominent Mexican painter. His large fre...
# 3  was a French painter, a founder of French Impr...
# 4  Was a Belgian Surrealist artist. He became wel...
#
#                                         wikipedia  paintings  \
# 0  http://en.wikipedia.org/wiki/Amedeo_Modigliani        193
# 1  http://en.wikipedia.org/wiki/Wassily_Kandinsky         88
# 2       http://en.wikipedia.org/wiki/Diego_Rivera         70
# 3       http://en.wikipedia.org/wiki/Claude_Monet         73
# 4      http://en.wikipedia.org/wiki/René_Magritte        194
#
#                  name
# 0   Amedeo Modigliani
# 1  Vasiliy Kandinskiy
# 2        Diego Rivera
# 3        Claude Monet
# 4       Rene Magritte

# %%
artists.shape
# Out:
# (5, 5)

# %%
artists.iloc[2]['name']
# Out:
# 'Diego Rivera'

# %%
biography.shape
# Out:
# (5, 7)

# %%
biography.iloc[4]['paintings']
# Out:
# np.int64(194)

# %%
biography.iloc[3]['name']
# Out:
# 'Claude Monet'

# %%
def test_artists_1():
    assert artists.shape == (5,5)
def test_artists_2():
    assert artists.iloc[2]['name'] == 'Diego Rivera'
def test_biography_1():
    assert biography.shape == (5,7)
def test_biography_2():
    assert biography.iloc[4]['paintings'] == 194
def test_biography_3():
    assert biography.iloc[3]['name'] == 'Claude Monet'

# %%
'Aa' in "1Aa"  # 只要字符串包含Aa即可
# Out:
# True

# %%
'Aa' in "1aA"  #
# Out:
# False

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/68501079-0695df00-023c-11ea-841f-455dac84a089.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Reading data from relational databases
#
# In this lesson you will learn how to read SQL queries and relational database tables into `DataFrame` objects using pandas. Also, we'll take a look at different techniques to persist that pandas `DataFrame` objects to database tables.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (2.0.40)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (4.13.1)

# %%
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Read data from SQL database
#
# Reading data from SQL relational databases is fairly simple and pandas support a variety of methods to deal with it.
#
# We'll start with an example using SQLite, as it's a builtin Python package, and we don't need anything extra installed.

# %%
import sqlite3

# %% [markdown]
# In order to work with a SQLite database from Python, we first have to connect to it. We can do that using the connect function, which returns a `Connection` object.
#
# We'll use [this example database](http://www.sqlitetutorial.net/sqlite-sample-database/).

# %%
conn = sqlite3.connect("chinook.db")  # 我们可以使用 connect 函数来实现，它返回一个 Connection 对象

# %% [markdown]
# Once we have a `Connection` object, we can then create a `Cursor` object. Cursors allow us to execute SQL queries against a database:

# %% [markdown]
# ###Cursor 对象。游标允许我们对数据库执行 SQL 查询：

# %%
cur = conn.cursor()

# %% [markdown]
# The `Cursor` created has a method `execute`, which will receive SQL parameters to run against the database.
#
# The code below will fetch the first `5` rows from the `employees` table:

# %%
cur.execute('SELECT * FROM employees LIMIT 5;')

# %% [markdown]
# You may have noticed that we didn't assign the result of the above query to a variable. This is because we need to run another command to actually fetch the results.
#
# We can use the `fetchall` method to fetch all of the results of a query:

# %%
results = cur.fetchall()

# %%
print(type(results), type(results[0]))
# Out:
# <class 'list'> <class 'tuple'>

# %%
results
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5G3',
#   '+1 (403) 263-4423',
#   '+1 (403) 263-4289',
#   'margaret@chinookcorp.com'),
#  (5,
#   'Johnson',
#   'Steve',
#   'Sales Support Agent',
#   2,
#   '1965-03-03 00:00:00',
#   '2003-10-17 00:00:00',
#   '7727B 41 Ave',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T3B 1Y7',
#   '1 (780) 836-9987',
#   '1 (780) 836-9543',
#   'steve@chinookcorp.com')]

# %% [markdown]
# As you can see, the results are returned as a list of tuples. Each tuple corresponds to a row in the database that we accessed. Dealing with data this way is painful.
#
# We'd need to manually add column headers, and manually parse the data. Luckily, the pandas library has an easier way, which we'll look at in the next section.

# %%
df = pd.DataFrame(results)

# %%
df.head()
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# 0  +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 1  +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 3  +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 4   1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# Before we move on, it's good practice to close `Connection` objects and `Cursor` objects that are open. This prevents the SQLite database from being locked. When a SQLite database is locked, you may be unable to update the database, and may get errors. We can close the Cursor and the Connection like this:

# %%
cur.close()
conn.close()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using pandas `read_sql` method
#
# We can use the pandas `read_sql` function to read the results of a SQL query directly into a pandas `DataFrame`. The code below will execute the same query that we just did, but it will return a `DataFrame`. It has several advantages over the query we did above:
#
# - It doesn't require us to create a `Cursor` object or call `fetchall` at the end.
# - It automatically reads in the names of the headers from the table.
# - It creates a `DataFrame`, so we can quickly explore the data.

# %% [markdown]
# ###创建一个链接对象还是必须的， 不需要游标对象。

# %%
conn = sqlite3.connect('chinook.db') #

# %%
df = pd.read_sql('SELECT * FROM employees;', conn)  # 直接从链接对象中查询员工表

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql('SELECT * FROM employees;', conn,
                 index_col='EmployeeId',
                 parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      object
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: datetime64[ns](2), float64(1), object(11)
# memory usage: 960.0+ bytes

# %%
df['ReportsTo'].isna()
# Out:
# EmployeeId
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: ReportsTo, dtype: bool

# %%
df['ReportsTo'].isna().sum()  # 判断有多个nan值
# Out:
# np.int64(1)

# %%
df['ReportsTo'].mean()  # 忽略nan值
# Out:
# np.float64(2.857142857142857)

# %%
df['ReportsTo'] > 1.75
# Out:
# EmployeeId
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# Name: ReportsTo, dtype: bool

# %%
df['City'] = df['City'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 1 to 8
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LastName    8 non-null      object
#  1   FirstName   8 non-null      object
#  2   Title       8 non-null      object
#  3   ReportsTo   7 non-null      float64
#  4   BirthDate   8 non-null      datetime64[ns]
#  5   HireDate    8 non-null      datetime64[ns]
#  6   Address     8 non-null      object
#  7   City        8 non-null      category
#  8   State       8 non-null      object
#  9   Country     8 non-null      object
#  10  PostalCode  8 non-null      object
#  11  Phone       8 non-null      object
#  12  Fax         8 non-null      object
#  13  Email       8 non-null      object
# dtypes: category(1), datetime64[ns](2), float64(1), object(10)
# memory usage: 1.0+ KB

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using pandas `read_sql_query` method
#
# It turns out that the `read_sql` method we saw above is just a wrapper around `read_sql_query` and `read_sql_table`.
#
# We can get the same result using `read_sql_query` method:

# %%
conn = sqlite3.connect('chinook.db')

# %%
df = pd.read_sql_query('SELECT * FROM employees LIMIT 5;', conn)

# %%
df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
df = pd.read_sql_query('SELECT * FROM employees;', conn,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using `read_sql_table` method
#
# `read_sql_table` is a useful function, but it works only with [SQLAlchemy](https://www.sqlalchemy.org/), a Python SQL Toolkit and Object Relational Mapper.
#
# This is just a demonstration of its usage where we read the whole `employees` table.

# %%
from sqlalchemy import create_engine

# %% [markdown]
# ###获取数据库的表名

# %%
import pandas as pd

# 使用 SQLAlchemy 引擎
engine = create_engine("sqlite:///chinook.db")

# 读取 SQLite 表名
df_tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", engine)
print("Pandas 读取表名:\n", df_tables)
# Out:
# Pandas 读取表名:
#                 name
# 0            albums
# 1   sqlite_sequence
# 2           artists
# 3         customers
# 4         employees
# 5            genres
# 6          invoices
# 7     invoice_items
# 8       media_types
# 9         playlists
# 10   playlist_track
# 11           tracks
# 12     sqlite_stat1
# 13       employees2

# %%
from sqlalchemy import create_engine, inspect

engine = create_engine('sqlite:///chinook.db')
connection = engine.connect()

# Use inspect to get the table names
inspector = inspect(engine)
table_names = inspector.get_table_names()

print(table_names)  # Print the list of table names

connection.close()  # Remember to close the connection
# Out:
# ['albums', 'artists', 'customers', 'employees', 'employees2', 'genres', 'invoice_items', 'invoices', 'media_types', 'playlist_track', 'playlists', 'tracks']

# %%
engine = create_engine('sqlite:///chinook.db')

connection = engine.connect()

# %%
df = pd.read_sql_table('employees', con=connection, columns=["LastName", "FirstName"])

# %%
df.head()
# Out:
#   LastName FirstName
# 0    Adams    Andrew
# 1  Edwards     Nancy
# 2  Peacock      Jane
# 3     Park  Margaret
# 4  Johnson     Steve

# %%
df = pd.read_sql_table('employees', con=connection,
                       index_col='EmployeeId',
                       parse_dates=['BirthDate', 'HireDate'])

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# ###记得操作完毕关闭数据库

# %%
connection.close()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Create tables from `DataFrame` objects
#
# Finally we can persist `DataFrame` objects we've working on in a database using the pandas `to_sql` method.
#
# Although it is easy to implement, it could be a very slow process.

# %%
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  BirthDate  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN 1962-02-18
# 2           Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 3           Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 4              Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 5           Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#              HireDate              Address      City State Country PostalCode  \
# EmployeeId
# 1          2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 2          2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 3          2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 4          2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 5          2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                         Phone                Fax                     Email
# EmployeeId
# 1           +1 (780) 428-9482  +1 (780) 428-3457    andrew@chinookcorp.com
# 2           +1 (403) 262-3443  +1 (403) 262-3322     nancy@chinookcorp.com
# 3           +1 (403) 262-3443  +1 (403) 262-6712      jane@chinookcorp.com
# 4           +1 (403) 263-4423  +1 (403) 263-4289  margaret@chinookcorp.com
# 5            1 (780) 836-9987   1 (780) 836-9543     steve@chinookcorp.com

# %% [markdown]
# ###不能添加相同的表， 需要额外的参数

# %%
df.to_sql('employees2', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-79386908e59c> in <cell line: 0>()
# ----> 1 df.to_sql('employees2', conn)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2848             dtype=dtype,
#    2849         )
# -> 2850         table.create()
#    2851         return table.insert(chunksize, method)
#    2852
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in create(self)
#     984         if self.exists():
#     985             if self.if_exists == "fail":
# --> 986                 raise ValueError(f"Table '{self.name}' already exists.")
#     987             if self.if_exists == "replace":
#     988                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'employees2' already exists.

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %% [markdown]
# ###删除表

# %%
#pd.read_sql_query('DROP TABLE employees2;', conn)

# %% [markdown]
# ## Custom behaviour
#
# The `if_exists` parameter define how to behave if the table already exists and adds a ton of flexibility, letting you decide wheather to `replace` current database data, `append` new data at the end, or simply `fail` if database already exists.

# %%
pd.DataFrame().to_sql('employees2',
                      conn,
                      if_exists='replace')
# Out:
# 0

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
# Empty DataFrame
# Columns: [index]
# Index: []

# %% [markdown]
# ###返回插入了多少条数据

# %%
df.to_sql('employees2',
          conn,
          if_exists='replace')
# Out:
# 8

# %%
pd.read_sql_query('SELECT * FROM employees2;', conn).head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %% [markdown]
# ###关闭数据库

# %% [markdown]
# 你遇到的错误 ObjectNotExecutableError: Not an executable object: 'SELECT * FROM employees2 LIMIT 5' 通常是由于传递给 connection.execute() 的参数不是可执行的 SQL 语句对象。在 SQLAlchemy 中，connection.execute() 方法期望的是一个 text() 对象或一个 SQL 表达式对象，而不是一个纯字符串。
#
# 解决方法
# 你可以使用 text() 函数将 SQL 字符串包装成一个可执行的 SQL 语句对象。text() 函数是 SQLAlchemy 提供的一个工具，用于将字符串转换为 SQL 表达式。

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('sqlite:///chinook.db')
with engine.connect() as connection:
    result = connection.execute("SELECT * FROM employees2 LIMIT 5")

    # 查看 result 的类型和方法
    print(type(result))          # <class 'sqlalchemy.engine.result.LegacyCursorResult'>
    print(dir(result))           # 可以看到 .keys() 方法

    # 获取列名
    print(result.keys())         # ['ArtistId', 'Name']

    # 获取数据（元组列表）
    rows = result.fetchall()
    print(rows)                 # [(1, 'AC/DC'), (2, 'Accept'), ...]

    # 转换为 DataFrame
    df = pd.DataFrame(rows, columns=result.keys())
    print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1411         try:
# -> 1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# <ipython-input-86-f4d488402dc5> in <cell line: 0>()
#       4 engine = create_engine('sqlite:///chinook.db')
#       5 with engine.connect() as connection:
# ----> 6     result = connection.execute("SELECT * FROM employees2 LIMIT 5")
#       7
#       8     # 查看 result 的类型和方法
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
# -> 1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
#    1416             return meth(
#
# ObjectNotExecutableError: Not an executable object: 'SELECT * FROM employees2 LIMIT 5'

# %%
from sqlalchemy import create_engine, text
import pandas as pd

engine = create_engine('sqlite:///chinook.db')
with engine.connect() as connection:
    # Use text() to create an executable SQL statement object
    result = connection.execute(text("SELECT * FROM employees2 LIMIT 5"))

    # 查看 result 的类型和方法
    print(type(result))          # <class 'sqlalchemy.engine.result.LegacyCursorResult'>
    print(dir(result))           # 可以看到 .keys() 方法

    # 获取列名
    print(result.keys())         # ['ArtistId', 'Name']

    # 获取数据（元组列表）
    rows = result.fetchall()
    print(rows)                 # [(1, 'AC/DC'), (2, 'Accept'), ...]

    # 转换为 DataFrame
    df = pd.DataFrame(rows, columns=result.keys())
    print(df)
# Out:
# <class 'sqlalchemy.engine.cursor.CursorResult'>
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '_allrows', '_assert_no_memoizations', '_attributes', '_column_slices', '_echo', '_fetchall_impl', '_fetchiter_impl', '_fetchmany_impl', '_fetchone_impl', '_generate', '_generate_rows', '_getter', '_init_metadata', '_is_cursor', '_is_protocol', '_iter_impl', '_iterator_getter', '_manyrow_getter', '_memoized_keys', '_metadata', '_next_impl', '_no_result_metadata', '_onerow_getter', '_only_one_row', '_post_creational_filter', '_raw_all_rows', '_raw_row_iterator', '_real_result', '_reset_memoizations', '_rewind', '_row_getter', '_row_logging_fn', '_set_memoized_attribute', '_soft_close', '_soft_closed', '_source_supports_scalars', '_tuple_getter', '_unique_filter_state', '_unique_strategy', '_yield_per', 'all', 'close', 'closed', 'columns', 'connection', 'context', 'cursor', 'cursor_strategy', 'dialect', 'fetchall', 'fetchmany', 'fetchone', 'first', 'freeze', 'inserted_primary_key', 'inserted_primary_key_rows', 'is_insert', 'keys', 'last_inserted_params', 'last_updated_params', 'lastrow_has_defaults', 'lastrowid', 'mappings', 'memoized_attribute', 'memoized_instancemethod', 'merge', 'one', 'one_or_none', 'partitions', 'postfetch_cols', 'prefetch_cols', 'returned_defaults', 'returned_defaults_rows', 'returns_rows', 'rowcount', 'scalar', 'scalar_one', 'scalar_one_or_none', 'scalars', 'splice_horizontally', 'splice_vertically', 'supports_sane_multi_rowcount', 'supports_sane_rowcount', 't', 'tuples', 'unique', 'yield_per']
# RMKeyView(['EmployeeId', 'LastName', 'FirstName', 'Title', 'ReportsTo', 'BirthDate', 'HireDate', 'Address', 'City', 'State', 'Country', 'PostalCode', 'Phone', 'Fax', 'Email'])
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'), (2, 'Edwards', 'Nancy', 'Sales Manager', 1.0, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'), (3, 'Peacock', 'Jane', 'Sales Support Agent', 2.0, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'), (4, 'Park', 'Margaret', 'Sales Support Agent', 2.0, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'), (5, 'Johnson', 'Steve', 'Sales Support Agent', 2.0, '1965-03-03 00:00:00', '2003-10-17 00:00:00', '7727B 41 Ave', 'Calgary', 'AB', 'Canada', 'T3B 1Y7', '1 (780) 836-9987', '1 (780) 836-9543', 'steve@chinookcorp.com')]
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# 0    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com

# %%
conn.close()

# %% [markdown]
# ###补充

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###方法 1：直接使用 pd.read_sql() 方法

# %%
from sqlalchemy import create_engine
import pandas as pd

# 创建数据库引擎
engine = create_engine('sqlite:///chinook.db')

# 直接使用 pd.read_sql() 执行查询
query = "SELECT * FROM employees2 LIMIT 5"
df = pd.read_sql(query, engine)

print(df)

# %% [markdown]
# ###方法 2：使用 engine.execute()（SQLAlchemy 1.x 风格）弃用

# %%
from sqlalchemy import create_engine
import pandas as pd

# 创建数据库引擎
engine = create_engine('sqlite:///chinook.db')

# 使用 engine.execute() 执行查询
result = engine.execute("SELECT * FROM employees2 LIMIT 5")

# 将结果转换为 DataFrame
df = pd.DataFrame(result.fetchall(), columns=result.keys())
print(df)

# %% [markdown]
# ###方法 3：使用 Session 对象
# 如果你使用的是 SQLAlchemy 的 ORM 模式，可以通过 Session 对象执行 SQL 查询。

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
import pandas as pd

# 创建数据库引擎
engine = create_engine('sqlite:///chinook.db')

# 创建 Session 对象
Session = sessionmaker(bind=engine)
session = Session()

# 使用 Session 执行查询
result = session.execute("SELECT * FROM employees2 LIMIT 5")

# 将结果转换为 DataFrame
df = pd.DataFrame(result.fetchall(), columns=result.keys())
print(df)

# 关闭 Session
session.close()

# %% [markdown]
# ###方法 4：使用 connection.exec_driver_sql()
# connection.exec_driver_sql() 是 SQLAlchemy 提供的一个底层方法，可以直接执行原生 SQL 查询。

# %%
from sqlalchemy import create_engine
import pandas as pd

# 创建数据库引擎
engine = create_engine('sqlite:///chinook.db')

# 使用 connection.exec_driver_sql() 执行查询
with engine.connect() as connection:
    result = connection.exec_driver_sql("SELECT * FROM employees2 LIMIT 5")

    # 将结果转换为 DataFrame
    df = pd.DataFrame(result.fetchall(), columns=result.keys())
    print(df)

# %% [markdown]
# ###方法 5：使用 sqlalchemy.sql.text() 和参数化查询
# 如果你需要执行参数化查询，可以使用 sqlalchemy.sql.text() 并结合参数绑定。

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# 创建数据库引擎
engine = create_engine('sqlite:///chinook.db')

# 使用 text() 和参数化查询
query = text("SELECT * FROM employees2 WHERE EmployeeId = :id")

# 执行查询
with engine.connect() as connection:
    result = connection.execute(query, id=1)

    # 将结果转换为 DataFrame
    df = pd.DataFrame(result.fetchall(), columns=result.keys())
    print(df)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
