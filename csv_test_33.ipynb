# %% [markdown]
# <a href="https://colab.research.google.com/github/hemu2014/python-data-test/blob/main/csv_test_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##读取数据（read_csv()）

# %%
import numpy as np
import pandas as pd

column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews', 'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     names=column_names, # 列名
                     skiprows=3) # 跳过前三行

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
movies.shape
# Out:
# (97, 13)

# %%
movies.loc[:, 'imdb_score'].max()
# Out:
# 9.0

# %%
movies.head()
# Out:
#    color      director_name num_critic_for_reviews duration        gross  \
# 0  Color  Christopher Nolan                  813.0    164.0  448130642.0
# 1      ?        Doug Walker                      ?        ?            ?
# 2  Color     Andrew Stanton                  462.0    132.0   73058679.0
# 3  Color          Sam Raimi                  392.0    156.0  336530303.0
# 4  Color       Nathan Greno                  324.0    100.0  200807262.0
#
#                                          movie_title num_user_for_reviews  \
# 0                             The Dark Knight Rises                2701.0
# 1  Star Wars: Episode VII - The Force Awakens    ...                    ?
# 2                                       John Carter                 738.0
# 3                                      Spider-Man 3                1902.0
# 4                                           Tangled                 387.0
#
#   country cotent_rating         budget title_year  imdb_score        genre
# ...

# %% [markdown]
# test

# %%
def test_score():
    assert movies.loc[:, 'imdb_score'].max() # == 9
def test_shape():
   assert movies.shape  #== (97, 13)

# %%
print(test_score())  # 无返回值
# Out:
# None

# %%
test_shape()  # 无返回值

# %% [markdown]
# .rmotr文件

# %%
type = "assignment"
uuid = "42e61e08-4bf2-4749-b7d8-8eb79b2bd7c0"
name = "Load movies dataset"

# %% [markdown]
# ##增加更多的参数

# %%
import numpy as np
import pandas as pd

column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews', 'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

movies = pd.read_csv('movies.csv',
                     sep='|',
                     header=None,
                     names=column_names,
                     na_values='?', # 将？转为nan
                     thousands=',', # 千分位分隔符
                     index_col='movie_title') # 将movises_title作为行索引

# %%
movies
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
# ...                                                   ...                ...
# Guardians of the Galaxy                             Color         James Gunn
# Interstellar                                        Color  Christopher Nolan
# Inception                                           Color  Christopher Nolan
# Godzilla Resurgence                                 Color       Hideaki Anno
# The Hobbit: An Unexpected Journey                   Color      Peter Jackson
#
# ...

# %% [markdown]
# test

# %%
movies.loc[:, 'budget'].min()
# Out:
# 105000000.0

# %%
movies.country.unique()
# Out:
# array(['USA', 'UK', nan, 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan'], dtype=object)

# %%
'?' not in movies.country.unique()
# Out:
# True

# %%
movies.shape
# Out:
# (100, 12)

# %%
def test_budget():
    assert movies.loc[:, 'budget'].min() == 105000000.0
def test_country():
    assert '?' not in movies.country.unique()
def test_shape():
    assert movies.shape == (100, 12)

# %% [markdown]
# .rmotr文件

# %%
type = "assignment"
uuid = "701f3965-060b-472d-b777-aa1109dca549"
name = "Advanced parsing on movies dataset"

# %% [markdown]
# ##读取tsv文件
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

col_names = ['Title', 'Air date', 'Production code', 'Season', 'Number in season',
             'Number in series', 'US viewers (million)', 'Views', 'IMDB rating']

select_cols = ['Title','Air date','Production code','IMDB rating']

simpsons = pd.read_csv('simpsons-episodes.tsv',
                 sep='\t',
                 encoding='UTF-8',
                 names=col_names,  # 指定列索引
                 usecols=select_cols, # 选择需要的列数据
                 skiprows=4, # 跳过前四行
                 index_col='Production code',
                 na_values=['no_val'],  # 将no_val转为nan
                 parse_dates=['Air date'])
# Out:
# <ipython-input-31-4f8a656c10be>:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   simpsons = pd.read_csv('simpsons-episodes.tsv',

# %%
simpsons
# Out:
#                                                              Title   Air date  \
# Production code
# 7F01             Two Cars in Every Garage and Three Eyes on Eve... 1990-01-11
# 7F08                                                           NaN 1990-11-15
# 7F06                                            Bart the Daredevil 1990-06-12
# NaN                                         Bart Gets Hit by a Car 1991-10-01
# 7F13                        Homer vs. Lisa and the 8th Commandment 1991-07-02
# ...                                                            ...        ...
# PABF07                                          At Long Last Leave 2012-02-19
# PABF08                                       How I Wet Your Mother 2012-11-03
# PABF18                                  Adventures in Baby-Getting 2012-04-11
# SABF08                                                       Diggs 2014-09-03
# SABF13                                       Days of Future Future 2014-04-13
#
# ...

# %% [markdown]
# test

# %%
simpsons['Air date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
simpsons.dtypes
# Out:
# Title                  object
# Air date       datetime64[ns]
# IMDB rating           float64
# dtype: object

# %%
simpsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 7F01 to SABF13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        575 non-null    object
#  1   Air date     597 non-null    datetime64[ns]
#  2   IMDB rating  592 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 34.8+ KB

# %%
simpsons.columns
# Out:
# Index(['Title', 'Air date', 'IMDB rating'], dtype='object')

# %%
simpsons.iloc[234, 2]
# Out:
# np.float64(6.6)

# %%
list(simpsons.columns)
# Out:
# ['Title', 'Air date', 'IMDB rating']

# %%
simpsons.shape
# Out:
# (597, 3)

# %%
def test_simpsons_columns():
    assert list(simpsons.columns) == ['Title', 'Air date', 'IMDB rating']
def test_simpsons_item():
    assert simpsons.iloc[234, 2] == 6.6
def test_simpsons_shape():
    assert simpsons.shape == (597, 3)

# %% [markdown]
# .rmotr文件

# %%
type = "assignment"
uuid = "d50c66f0-e9b6-4426-b52c-21d461f1e935"
name = "TSV with The Simpsons episodes"
