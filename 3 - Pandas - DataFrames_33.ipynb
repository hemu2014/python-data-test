# %% [markdown]
# <a href="https://colab.research.google.com/github/hemu2014/python-data-test/blob/main/3%20-%20Pandas%20-%20DataFrames_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/75165824-badf4680-5701-11ea-9c5b-5475b0a33abf.png"
#     style="width:300px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Pandas - `DataFrame`s
#
# Probably the most important data structure of pandas is the `DataFrame`. It's a tabular structure tightly integrated with `Series`.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We'll keep our analysis of G7 countries and looking now at DataFrames. As said, a DataFrame looks a lot like a table (as the one you can appreciate [here](https://docs.google.com/spreadsheets/d/1IlorV2-Oh9Da1JAZ7weVw86PQrQydSMp-ydVMH135iI/edit?usp=sharing)):
#
# <img width="700" src="https://user-images.githubusercontent.com/872296/38153492-72c032ca-3443-11e8-80f4-9de9060a5127.png" />
#
# Creating `DataFrame`s manually can be tedious. 99% of the time you'll be pulling the data from a Database, a csv file or the web. But still, you can create a DataFrame by specifying the columns and values:

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
},columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent', "test"])

# %% [markdown]
# _(The `columns` attribute is optional. I'm using it to keep the same order as in the picture above)_

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent test
# 0      35.467   1785387       9984670  0.913   America  NaN
# 1      63.951   2833687        640679  0.888    Europe  NaN
# 2      80.940   3874437        357114  0.916    Europe  NaN
# 3      60.665   2167744        301336  0.873    Europe  NaN
# 4     127.061   4602367        377930  0.891      Asia  NaN
# 5      64.511   2950039        242495  0.907    Europe  NaN
# 6     318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# `DataFrame`s also have indexes. As you can see in the "table" above, pandas has assigned a numeric, autoincremental index automatically to each "row" in our DataFrame. In our case, we know that each row represents a country, so we'll just reassign the index:

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# columns--数据帧的列名

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent', 'test'], dtype='object')

# %% [markdown]
# index--数据帧的索引，行名

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %% [markdown]
# info---数据帧的基础信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
#  5   test          0 non-null      object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 692.0+ bytes

# %% [markdown]
# size ---数据帧的数据个数

# %%
df.size # 6*7 = 42
# Out:
# 42

# %% [markdown]
# shape--数据帧的行列数

# %%
df.shape
# Out:
# (7, 6)

# %% [markdown]
# describe()--数据帧的数学描述

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Population'].plot(kind='hist', bins=20, title='Population')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['GDP'].plot(kind='hist', bins=20, title='GDP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Surface Area'].plot(kind='hist', bins=20, title='Surface Area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['HDI'].plot(kind='hist', bins=20, title='HDI')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Population', y='GDP', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='GDP', y='Surface Area', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Surface Area', y='HDI', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Population'].plot(kind='line', figsize=(8, 4), title='Population')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['GDP'].plot(kind='line', figsize=(8, 4), title='GDP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Surface Area'].plot(kind='line', figsize=(8, 4), title='Surface Area')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['HDI'].plot(kind='line', figsize=(8, 4), title='HDI')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# *dtypes*--数据帧的数据类型

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# test             object
# dtype: object

# %% [markdown]
# value_counts()--对相同的数据进行分组

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Indexing, Selection and Slicing
#
# Individual columns in the DataFrame can be selected with regular indexing. Each column is represented as a `Series`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# loc[ ]--通过行名提取数据

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# test                NaN
# Name: Canada, dtype: object

# %% [markdown]
# iloc[ ]--位置参数提取数据

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# test                 NaN
# Name: United States, dtype: object

# %% [markdown]
# df[]---通过列名进行提取数据

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %% [markdown]
# Note that the `index` of the returned Series is the same as the DataFrame one. And its `name` is the name of the column. If you're working on a notebook and want to see a more DataFrame-like format you can use the `to_frame` method:

# %% [markdown]
# 处理series时可以使用。to_frame(),为dataframe时不需要使用

# %%
df[['Population', 'GDP']].to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-44a64cad30fd> in <cell line: 0>()
# ----> 1 df[['Population', 'GDP']].to_frame()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %% [markdown]
# Multiple columns can also be selected similarly to `numpy` and `Series`:

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %% [markdown]
# In this case, the result is another `DataFrame`. Slicing works differently, it acts at "row level", and can be counter intuitive:

# %% [markdown]
# df[1:3]---在这种情况下，结果是另一个 DataFrame 。切片操作不同，它在“行级别”上操作，可能具有反直觉性：

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent test
# France       63.951  2833687        640679  0.888    Europe  NaN
# Germany      80.940  3874437        357114  0.916    Europe  NaN

# %%
df.loc['France': "Germany"]
# Out:
#          Population      GDP  Surface Area    HDI Continent test
# France       63.951  2833687        640679  0.888    Europe  NaN
# Germany      80.940  3874437        357114  0.916    Europe  NaN

# %%
df.iloc[1: 3]
# Out:
#          Population      GDP  Surface Area    HDI Continent test
# France       63.951  2833687        640679  0.888    Europe  NaN
# Germany      80.940  3874437        357114  0.916    Europe  NaN

# %% [markdown]
# Row level selection works better with `loc` and `iloc` **which are recommended** over regular "direct slicing" (`df[:]`).
#
# `loc` selects rows matching the given index:

# %%
df.loc['Italy']
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# test                NaN
# Name: Italy, dtype: object

# %%
df.loc['France': 'Italy']
# Out:
#          Population      GDP  Surface Area    HDI Continent test
# France       63.951  2833687        640679  0.888    Europe  NaN
# Germany      80.940  3874437        357114  0.916    Europe  NaN
# Italy        60.665  2167744        301336  0.873    Europe  NaN

# %% [markdown]
# As a second "argument", you can pass the column(s) you'd like to select:

# %%
df.loc['France': 'Italy', 'Population']
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc['France': 'Italy', ['Population', 'GDP']]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %% [markdown]
# `iloc` works with the (numeric) "position" of the index:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# test                NaN
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# test                 NaN
# Name: United States, dtype: object

# %%
df.iloc[[0, 1, -1]]
# Out:
#                Population       GDP  Surface Area    HDI Continent test
# Canada             35.467   1785387       9984670  0.913   America  NaN
# France             63.951   2833687        640679  0.888    Europe  NaN
# United States     318.523  17348075       9525067  0.915   America  NaN

# %%
df.iloc[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent test
# France       63.951  2833687        640679  0.888    Europe  NaN
# Germany      80.940  3874437        357114  0.916    Europe  NaN

# %% [markdown]
# iloc[1:2, 3]--第一个参数是选择，第二个参数是列选择(可以使用列表，也可以使用切片操作)

# %%
df.iloc[1:3, 3]
# Out:
# France     0.888
# Germany    0.916
# Name: HDI, dtype: float64

# %%
df.iloc[1:3, [0, 3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3, 1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %% [markdown]
# > **RECOMMENDED: Always use `loc` and `iloc` to reduce ambiguity, specially with `DataFrame`s with numeric indexes.**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Conditional selection (boolean arrays)
#
# We saw conditional selection applied to `Series` and it'll work in the same way for `DataFrame`s. After all, a `DataFrame` is a collection of `Series`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df['Population'] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %% [markdown]
# loc[]--记得是处理行数据，将人口数大于70的过滤出来

# %%
df.loc[df['Population'] > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent test
# Germany            80.940   3874437        357114  0.916    Europe  NaN
# Japan             127.061   4602367        377930  0.891      Asia  NaN
# United States     318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# The boolean matching is done at Index level, so you can filter by any row, as long as it contains the right indexes. Column selection still works as expected:

# %% [markdown]
# 与前面的方法类似

# %%
df.loc[df['Population'] > 70, 'Population']
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population'] > 70, ['Population', 'GDP']]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Dropping stuff
#
# Opposed to the concept of selection, we have "dropping". Instead of pointing out which values you'd like to _select_ you could point which ones you'd like to `drop`:

# %% [markdown]
# **drop（）**--丢弃数据,不会对原数据帧进行修改，而是返回一个新的数据帧

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df.drop(['Canada', 'Japan'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df.drop(columns=['Population', 'HDI', "test"])
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %% [markdown]
# 使用axis参数时--注意行列（0为行，1为列）

# %%
df.drop(['Italy', 'Canada'], axis=0)
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#                      GDP  Surface Area Continent test
# Canada           1785387       9984670   America  NaN
# France           2833687        640679    Europe  NaN
# Germany          3874437        357114    Europe  NaN
# Italy            2167744        301336    Europe  NaN
# Japan            4602367        377930      Asia  NaN
# United Kingdom   2950039        242495    Europe  NaN
# United States   17348075       9525067   America  NaN

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#                      GDP  Surface Area Continent test
# Canada           1785387       9984670   America  NaN
# France           2833687        640679    Europe  NaN
# Germany          3874437        357114    Europe  NaN
# Italy            2167744        301336    Europe  NaN
# Japan            4602367        377930      Asia  NaN
# United Kingdom   2950039        242495    Europe  NaN
# United States   17348075       9525067   America  NaN

# %%
df.drop(['Population', 'HDI'], axis='columns')
# Out:
#                      GDP  Surface Area Continent test
# Canada           1785387       9984670   America  NaN
# France           2833687        640679    Europe  NaN
# Germany          3874437        357114    Europe  NaN
# Italy            2167744        301336    Europe  NaN
# Japan            4602367        377930      Asia  NaN
# United Kingdom   2950039        242495    Europe  NaN
# United States   17348075       9525067   America  NaN

# %%
df.drop(['Canada', 'Germany'], axis='rows')
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# France              63.951   2833687        640679  0.888    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}, index=['row1', 'row2', 'row3'])

# 删除单行（按行名）
df.drop('row1', axis=0)  # 或 df.drop(index='row1')

# 删除多行
#df.drop(['row1', 'row2'])  # 默认 axis=0 可省略
# Out:
#       A  B  C
# row2  2  5  8
# row3  3  6  9

# %% [markdown]
# All these `drop` methods return a new `DataFrame`. If you'd like to modify it "in place", you can use the `inplace` attribute (there's an example below).

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Operations

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %% [markdown]
# 与series类似--在列级别进行操作

# %%
df[['Population', 'GDP']] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %% [markdown]
# **Operations with Series** work at a column level, broadcasting down the rows (which can be counter intuitive).

# %%
crisis = pd.Series([-1_000_000, -0.3], index=['GDP1', 'HDI'])
crisis
# Out:
# GDP1   -1000000.0
# HDI          -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %% [markdown]
# 分别对GDP与HDI两列分别进行操作

# %% [markdown]
# 注意索引名称需一致，否则会导致数据错误

# %%
crisis11 = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])
crisis11
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                 GDP  GDP1    HDI
# Canada          NaN   NaN  0.613
# France          NaN   NaN  0.588
# Germany         NaN   NaN  0.616
# Italy           NaN   NaN  0.573
# Japan           NaN   NaN  0.591
# United Kingdom  NaN   NaN  0.607
# United States   NaN   NaN  0.615

# %%
df[['GDP', 'HDI']] + crisis11
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %% [markdown]
# 方法可行，但不推荐

# %%
df[['GDP', 'HDI']] + {"GDP": 12323, "HDI": 34}
# Out:
#                      GDP     HDI
# Canada           1797710  34.913
# France           2846010  34.888
# Germany          3886760  34.916
# Italy            2180067  34.873
# Japan            4614690  34.891
# United Kingdom   2962362  34.907
# United States   17360398  34.915

# %%
df[['GDP', 'HDI']] + [1100, 100]
# Out:
#                      GDP      HDI
# Canada           1786487  100.913
# France           2834787  100.888
# Germany          3875537  100.916
# Italy            2168844  100.873
# Japan            4603467  100.891
# United Kingdom   2951139  100.907
# United States   17349175  100.915

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Modifying DataFrames
#
# It's simple and intuitive, You can add columns, or replace values for columns without issues:

# %% [markdown]
# ### Adding a new column

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test  \
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN
#
#                Language
# Canada              NaN
# France           French
# Germany          German
# Italy           Italian
# Japan               NaN
# United Kingdom      NaN
# United States       NaN

# %% [markdown]
# ---
# ### Replacing values per column

# %% [markdown]
# 对列进行操作

# %%
df['Language'] = 'English'

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test  \
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN
#
#                Language
# Canada          English
# France          English
# Germany         English
# Italy           English
# Japan           English
# United Kingdom  English
# United States   English

# %% [markdown]
# ---
# ### Renaming Columns

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test  \
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN
#
#                Language
# Canada          English
# France          English
# Germany         English
# Italy           English
# Japan           English
# United Kingdom  English
# United States   English

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'
    }, index={
        'United States': 'USA',
        'United Kingdom': 'UK',
        'Argentina': 'AR'
    })
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada       35.467   1785387       9984670                    0.913
# France       63.951   2833687        640679                    0.888
# Germany      80.940   3874437        357114                    0.916
# Italy        60.665   2167744        301336                    0.873
# Japan       127.061   4602367        377930                    0.891
# UK           64.511   2950039        242495                    0.907
# USA         318.523  17348075       9525067                    0.915
#
#         Continent test Language
# Canada    America  NaN  English
# France     Europe  NaN  English
# Germany    Europe  NaN  English
# Italy      Europe  NaN  English
# Japan        Asia  NaN  English
# UK         Europe  NaN  English
# USA       America  NaN  English

# %%
df.rename(index=str.upper)
# Out:
#                 Population       GDP  Surface Area    HDI Continent test  \
# CANADA              35.467   1785387       9984670  0.913   America  NaN
# FRANCE              63.951   2833687        640679  0.888    Europe  NaN
# GERMANY             80.940   3874437        357114  0.916    Europe  NaN
# ITALY               60.665   2167744        301336  0.873    Europe  NaN
# JAPAN              127.061   4602367        377930  0.891      Asia  NaN
# UNITED KINGDOM      64.511   2950039        242495  0.907    Europe  NaN
# UNITED STATES      318.523  17348075       9525067  0.915   America  NaN
#
#                Language
# CANADA          English
# FRANCE          English
# GERMANY         English
# ITALY           English
# JAPAN           English
# UNITED KINGDOM  English
# UNITED STATES   English

# %% [markdown]
# str.upper与str.lower---等价于 x.upper() , x.lower()

# %%
df.rename(columns=lambda x: x.upper())
# Out:
#                 POPULATION       GDP  SURFACE AREA    HDI CONTINENT TEST  \
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN
#
#                LANGUAGE
# Canada          English
# France          English
# Germany         English
# Italy           English
# Japan           English
# United Kingdom  English
# United States   English

# %%
df.rename(columns=str.lower)
# Out:
#                 population       gdp  surface area    hdi continent test  \
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN
#
#                language
# Canada          English
# France          English
# Germany         English
# Italy           English
# Japan           English
# United Kingdom  English
# United States   English

# %%
df.rename(index=lambda x: x.lower())
# Out:
#                 Population       GDP  Surface Area    HDI Continent test  \
# canada              35.467   1785387       9984670  0.913   America  NaN
# france              63.951   2833687        640679  0.888    Europe  NaN
# germany             80.940   3874437        357114  0.916    Europe  NaN
# italy               60.665   2167744        301336  0.873    Europe  NaN
# japan              127.061   4602367        377930  0.891      Asia  NaN
# united kingdom      64.511   2950039        242495  0.907    Europe  NaN
# united states      318.523  17348075       9525067  0.915   America  NaN
#
#                Language
# canada          English
# france          English
# germany         English
# italy           English
# japan           English
# united kingdom  English
# united states   English

# %% [markdown]
# ---
# ### Dropping columns

# %% [markdown]
# df.drop(columns='Language', inplace=True)--使用inplace参数，否则不会对原数据帧进行修改

# %%
df.drop(columns='Language', inplace=True)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# ---
# ### Adding values

# %% [markdown]
# append() 已被弃用
#
# Pandas 官方推荐改用 pd.concat() 或直接使用 DataFrame.loc[] 添加数据。
#
# 如果你使用的是 Pandas 1.4.0+，调用 append() 会收到 FutureWarning，而在 Pandas 2.0+ 会直接报 AttributeError。

# %%
pd.Series({
    'Population': 300000000000,
    'GDP': 5000000000000
})
# Out:
# Population     300000000000
# GDP           5000000000000
# dtype: int64

# %% [markdown]
# 这样对原数据进行了修改，有问题

# %%
df.loc['China'] = pd.Series({
    'Population': 300000000000,
    'GDP': 5000000000000
})
df
# Out:
#                   Population           GDP  Surface Area    HDI Continent  \
# Canada          3.546700e+01  1.785387e+06     9984670.0  0.913   America
# France          6.395100e+01  2.833687e+06      640679.0  0.888    Europe
# Germany         8.094000e+01  3.874437e+06      357114.0  0.916    Europe
# Italy           6.066500e+01  2.167744e+06      301336.0  0.873    Europe
# Japan           1.270610e+02  4.602367e+06      377930.0  0.891      Asia
# United Kingdom  6.451100e+01  2.950039e+06      242495.0  0.907    Europe
# United States   3.185230e+02  1.734808e+07     9525067.0  0.915   America
# China           3.000000e+11  5.000000e+12           NaN    NaN       NaN
#
#                test  China
# Canada          NaN    NaN
# France          NaN    NaN
# Germany         NaN    NaN
# Italy           NaN    NaN
# Japan           NaN    NaN
# United Kingdom  NaN    NaN
# United States   NaN    NaN
# China           NaN    NaN

# %% [markdown]
# 列的数量必须相对应

# %%
df.loc['te'] = [3,4]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-15933139bd01> in <cell line: 0>()
# ----> 1 df.loc['te'] = [3,4]
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#     912
#     913     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1930
#    1931             if missing:
# -> 1932                 self._setitem_with_indexer_missing(indexer, value)
#    1933                 return
#    1934
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2304                     # must have conforming columns
#    2305                     if len(value) != len(self.obj.columns):
# -> 2306                         raise ValueError("cannot set a row with mismatched columns")
#    2307
#    2308                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %% [markdown]
# 使用concat方法连接两个数据帧

# %%
new_row = pd.DataFrame({
    'Population': [3],
    'GDP': [5]
}, index=['test34'])  # index 指定行名

df = pd.concat([df, new_row])
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387     9984670.0  0.913   America  NaN
# France              63.951   2833687      640679.0  0.888    Europe  NaN
# Germany             80.940   3874437      357114.0  0.916    Europe  NaN
# Italy               60.665   2167744      301336.0  0.873    Europe  NaN
# Japan              127.061   4602367      377930.0  0.891      Asia  NaN
# United Kingdom      64.511   2950039      242495.0  0.907    Europe  NaN
# United States      318.523  17348075     9525067.0  0.915   America  NaN
# test34               3.000         5           NaN    NaN       NaN  NaN
# test34               3.000         3           NaN    NaN       NaN  NaN
# test34               3.000         5           NaN    NaN       NaN  NaN

# %% [markdown]
# Append returns a new `DataFrame`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %% [markdown]
# You can directly set the new index and values to the `DataFrame`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387       9984670  0.913   America  NaN
# France              63.951   2833687        640679  0.888    Europe  NaN
# Germany             80.940   3874437        357114  0.916    Europe  NaN
# Italy               60.665   2167744        301336  0.873    Europe  NaN
# Japan              127.061   4602367        377930  0.891      Asia  NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe  NaN
# United States      318.523  17348075       9525067  0.915   America  NaN

# %%
df.loc['China'] = pd.Series({'Population': 1_400_000_000, 'Continent': 'Asia'})

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent test
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America  NaN
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe  NaN
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe  NaN
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe  NaN
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia  NaN
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe  NaN
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America  NaN
# China           1.400000e+09         NaN           NaN    NaN      Asia  NaN

# %% [markdown]
# We can use `drop` to just remove a row by index:

# %%
df.drop('China', inplace=True)

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent test
# Canada              35.467   1785387.0     9984670.0  0.913   America  NaN
# France              63.951   2833687.0      640679.0  0.888    Europe  NaN
# Germany             80.940   3874437.0      357114.0  0.916    Europe  NaN
# Italy               60.665   2167744.0      301336.0  0.873    Europe  NaN
# Japan              127.061   4602367.0      377930.0  0.891      Asia  NaN
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe  NaN
# United States      318.523  17348075.0     9525067.0  0.915   America  NaN

# %% [markdown]
# ---
# ### More radical index changes

# %%
df.reset_index()
# Out:
#             index  Population         GDP  Surface Area    HDI Continent test
# 0          Canada      35.467   1785387.0     9984670.0  0.913   America  NaN
# 1          France      63.951   2833687.0      640679.0  0.888    Europe  NaN
# 2         Germany      80.940   3874437.0      357114.0  0.916    Europe  NaN
# 3           Italy      60.665   2167744.0      301336.0  0.873    Europe  NaN
# 4           Japan     127.061   4602367.0      377930.0  0.891      Asia  NaN
# 5  United Kingdom      64.511   2950039.0      242495.0  0.907    Europe  NaN
# 6   United States     318.523  17348075.0     9525067.0  0.915   America  NaN

# %% [markdown]
# 设置标签

# %%
df.set_index('Population')
# Out:
#                    GDP  Surface Area    HDI Continent test
# Population
# 35.467       1785387.0     9984670.0  0.913   America  NaN
# 63.951       2833687.0      640679.0  0.888    Europe  NaN
# 80.940       3874437.0      357114.0  0.916    Europe  NaN
# 60.665       2167744.0      301336.0  0.873    Europe  NaN
# 127.061      4602367.0      377930.0  0.891      Asia  NaN
# 64.511       2950039.0      242495.0  0.907    Europe  NaN
# 318.523     17348075.0     9525067.0  0.915   America  NaN

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Creating columns from other columns
#
# Altering a DataFrame often involves combining different columns into another. For example, in our Countries analysis, we could try to calculate the "GDP per capita", which is just, `GDP / Population`.

# %%
df[['Population', 'GDP']]
# Out:
#                 Population         GDP
# Canada              35.467   1785387.0
# France              63.951   2833687.0
# Germany             80.940   3874437.0
# Italy               60.665   2167744.0
# Japan              127.061   4602367.0
# United Kingdom      64.511   2950039.0
# United States      318.523  17348075.0

# %% [markdown]
# The regular pandas way of expressing that, is just dividing each series:

# %%
df['GDP'] / df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# dtype: float64

# %% [markdown]
# The result of that operation is just another series that you can add to the original `DataFrame`:

# %% [markdown]
# 更正常操作一样，好好理解

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent test  \
# Canada              35.467   1785387.0     9984670.0  0.913   America  NaN
# France              63.951   2833687.0      640679.0  0.888    Europe  NaN
# Germany             80.940   3874437.0      357114.0  0.916    Europe  NaN
# Italy               60.665   2167744.0      301336.0  0.873    Europe  NaN
# Japan              127.061   4602367.0      377930.0  0.891      Asia  NaN
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe  NaN
# United States      318.523  17348075.0     9525067.0  0.915   America  NaN
#
#                 GDP Per Capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Statistical info
#
# You've already seen the `describe` method, which gives you a good "summary" of the `DataFrame`. Let's explore other methods in more detail:

# %% [markdown]
# 默认前5条数据

# %%
df.head()
# Out:
#          Population        GDP  Surface Area    HDI Continent test  \
# Canada       35.467  1785387.0     9984670.0  0.913   America  NaN
# France       63.951  2833687.0      640679.0  0.888    Europe  NaN
# Germany      80.940  3874437.0      357114.0  0.916    Europe  NaN
# Italy        60.665  2167744.0      301336.0  0.873    Europe  NaN
# Japan       127.061  4602367.0      377930.0  0.891      Asia  NaN
#
#          GDP Per Capita
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI  GDP Per Capita
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330

# %%
population = df['Population']

# %%
population.min(), population.max()
# Out:
# (35.467, 318.523)

# %%
population.sum()
# Out:
# np.float64(751.118)

# %% [markdown]
# 平均数

# %%
population.sum() / len(population)
# Out:
# np.float64(107.30257142857144)

# %%
population.mean()
# Out:
# np.float64(107.30257142857144)

# %% [markdown]
# 标准差

# %%
population.std()
# Out:
# 97.24996987121581

# %% [markdown]
# 中位数

# %%
population.median()
# Out:
# 64.511

# %%
population.describe()
# Out:
# count      7.000000
# mean     107.302571
# std       97.249970
# min       35.467000
# 25%       62.308000
# 50%       64.511000
# 75%      104.000500
# max      318.523000
# Name: Population, dtype: float64

# %% [markdown]
# population.quantile([0.2, 0.4, 0.6, 0.8, 1]) 是 Pandas 中的一个分位数计算操作，用于计算 population 这个 Series 或 DataFrame 列的分位数值

# %%
population.quantile(.25)
# Out:
# np.float64(62.308)

# %% [markdown]
# 📌 分位数（Quantile）是什么？
# 分位数是将数据集 按数值大小划分为若干等份 的点。例如：
#
# 中位数（Median） 是 0.5 分位数（即 50% 的数据 ≤ 中位数）。
#
# 0.25 分位数表示 25% 的数据 ≤ 该值（第一四分位数）。
#
# 1.0 分位数就是 最大值。

# %%
population.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
