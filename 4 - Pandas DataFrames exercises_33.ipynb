# %% [markdown]
# <a href="https://colab.research.google.com/github/hemu2014/python-data-test/blob/main/4%20-%20Pandas%20DataFrames%20exercises_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df = pd.DataFrame(data=marvel_data, columns=["1", "3", "34"])
marvel_df
# Out:
#                    1       3    34
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
col_names = ['name', 'sex', 'first_appearance']
marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.set_index('name')
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %% [markdown]
# drop（）函数，axis为1代表列。axis为0代表行，默认行

# %%
# your code goes here
marvel_df1 = marvel_df.drop(['name'], axis=1)

# %%
marvel_df1
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
marvel_df2 = marvel_df.drop(['Namor', "Hank Pym"])
marvel_df2
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
marvel_df.iloc[0:5]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# 不推荐

# %%
marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# 通过索引

# %%
marvel_df.loc['Spider-Man': 'Thor', :]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# 通过位置iloc

# %%
marvel_df.iloc[0:5, :]
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %% [markdown]
# 默认后5条数据

# %%
# your code goes here
marvel_df.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# 数据时从后往前取得

# %%
marvel_df.iloc[-1:-6:-1]
# Out:
#                    sex  first_appearance
# name
# Vision            male              1968
# Black Widow     female              1964
# Wasp            female              1963
# Scarlet Witch   female              1964
# Doctor Strange    male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[:5,]['sex']
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %% [markdown]
# [marvel_df.index[:5],获取前五条数据， 在选择sex列

# %%
marvel_df.loc[marvel_df.index[:5], "sex"]
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
marvel_df.iloc[:5,].sex.to_frame()
# or
marvel_df.head().sex.to_frame()
# or
marvel_df.loc[marvel_df.index[:5], "sex"]
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
marvel_df.loc[marvel_df.index[1:-1], "first_appearance"]
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appearance, dtype: int64

# %%
# your code goes here
marvel_df.iloc[1:-1]["first_appearance"].to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0, -1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %% [markdown]
# 不要忘记loc,是行的索引值，df[ ]--是默认列名

# %%
# your code goes here
marvel_df.loc['Vision', 'first_appearance'] = 1964
marvel_df.loc['Vision']
# Out:
# sex                 male
# first_appearance    1964
# Name: Vision, dtype: object

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1967

marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since'] = 2017 - marvel_df['first_appearance']
marvel_df
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1962           55
# Captain America     male              1941           76
# Wolverine           male              1974           43
# Iron Man            male              1963           54
# Thor                male              1963           54
# Thing               male              1961           56
# Mister Fantastic    male              1961           56
# Hulk                male              1962           55
# Beast               male              1963           54
# Invisible Woman   female              1961           56
# Storm             female              1975           42
# Hawkeye             male              1964           53
# Daredevil           male              1964           53
# Doctor Strange      male              1963           54
# Scarlet Witch     female              1964           53
# Wasp              female              1963           54
# ...

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1962           56
# Captain America     male              1941           77
# Wolverine           male              1974           44
# Iron Man            male              1963           55
# Thor                male              1963           55
# Thing               male              1961           57
# Mister Fantastic    male              1961           57
# Hulk                male              1962           56
# Beast               male              1963           55
# Invisible Woman   female              1961           57
# Storm             female              1975           43
# Hawkeye             male              1964           54
# Daredevil           male              1964           54
# Doctor Strange      male              1963           55
# Scarlet Witch     female              1964           54
# Wasp              female              1963           55
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask = marvel_df['sex'] == 'male'
mask
# Out:
# name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask = marvel_df['sex'] == 'female'

marvel_df[mask]
# Out:
#                     sex  first_appearance  years_since
# name
# Invisible Woman  female              1961           57
# Storm            female              1975           43
# Scarlet Witch    female              1964           54
# Wasp             female              1963           55
# Black Widow      female              1964           54

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]
# Out:
#                    sex  first_appearance  years_since
# name
# Spider-Man        male              1962           56
# Captain America   male              1941           77
# Wolverine         male              1974           44
# Iron Man          male              1963           55
# Thor              male              1963           55
# Thing             male              1961           57
# Mister Fantastic  male              1961           57
# Hulk              male              1962           56
# Beast             male              1963           55
# Hawkeye           male              1964           54
# Daredevil         male              1964           54
# Doctor Strange    male              1963           55
# Vision            male              1967           51

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
marvel_df[marvel_df["first_appearance"] > 1970]
# Out:
#               sex  first_appearance  years_since
# name
# Wolverine    male              1974           44
# Storm      female              1975           43

# %%
marvel_df.loc[marvel_df['first_appearance'] > 1970]
# Out:
#               sex  first_appearance  years_since
# name
# Wolverine    male              1974           44
# Storm      female              1975           43

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
#               sex  first_appearance  years_since
# name
# Wolverine    male              1974           44
# Storm      female              1975           43

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
marvel_df.loc[(marvel_df['sex'] == "female") & (marvel_df['first_appearance'] > 1970), ["sex", "first_appearance"]]
# Out:
#           sex  first_appearance
# name
# Storm  female              1975

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]
# Out:
#           sex  first_appearance  years_since
# name
# Storm  female              1975           43

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Spider-Man to Vision
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sex               18 non-null     object
#  1   first_appearance  18 non-null     int64
#  2   years_since       18 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         18.000000    18.000000
# mean        1963.055556    54.944444
# std            6.786424     6.786424
# min         1941.000000    43.000000
# 25%         1962.000000    54.000000
# 50%         1963.000000    55.000000
# 75%         1964.000000    56.000000
# max         1975.000000    77.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].mean()
# Out:
# np.float64(1963.0555555555557)

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()
# Out:
# np.float64(1963.0555555555557)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].min()
# Out:
# 1941

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()
# Out:
# 1941

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
marvel_df[marvel_df['first_appearance'] == marvel_df['first_appearance'].min()]
# Out:
#                   sex  first_appearance  years_since
# name
# Captain America  male              1941           77

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#                   sex  first_appearance  years_since
# name
# Captain America  male              1941           77

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df.reset_index()
# Out:
#     index              name     sex  first_appearance  years_since
# 0       0        Spider-Man    male              1962           56
# 1       1   Captain America    male              1941           77
# 2       2         Wolverine    male              1974           44
# 3       3          Iron Man    male              1963           55
# 4       4              Thor    male              1963           55
# 5       5             Thing    male              1961           57
# 6       6  Mister Fantastic    male              1961           57
# 7       7              Hulk    male              1962           56
# 8       8             Beast    male              1963           55
# 9       9   Invisible Woman  female              1961           57
# 10     10             Storm  female              1975           43
# 11     11           Hawkeye    male              1964           54
# 12     12         Daredevil    male              1964           54
# ...

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#     index              name     sex  first_appearance  years_since
# 0       0        Spider-Man    male              1962           56
# 1       1   Captain America    male              1941           77
# 2       2         Wolverine    male              1974           44
# 3       3          Iron Man    male              1963           55
# 4       4              Thor    male              1963           55
# 5       5             Thing    male              1961           57
# 6       6  Mister Fantastic    male              1961           57
# 7       7              Hulk    male              1962           56
# 8       8             Beast    male              1963           55
# 9       9   Invisible Woman  female              1961           57
# 10     10             Storm  female              1975           43
# 11     11           Hawkeye    male              1964           54
# 12     12         Daredevil    male              1964           54
# ...

# %% [markdown]
# 没有对原数组进行更改

# %%
marvel_df.set_index('name')
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1962           56
# Captain America     male              1941           77
# Wolverine           male              1974           44
# Iron Man            male              1963           55
# Thor                male              1963           55
# Thing               male              1961           57
# Mister Fantastic    male              1961           57
# Hulk                male              1962           56
# Beast               male              1963           55
# Invisible Woman   female              1961           57
# Storm             female              1975           43
# Hawkeye             male              1964           54
# Daredevil           male              1964           54
# Doctor Strange      male              1963           55
# Scarlet Witch     female              1964           54
# Wasp              female              1963           55
# ...

# %%
marvel_df.head()
# Out:
#               name   sex  first_appearance  years_since
# 0       Spider-Man  male              1962           56
# 1  Captain America  male              1941           77
# 2        Wolverine  male              1974           44
# 3         Iron Man  male              1963           55
# 4             Thor  male              1963           55

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].plot()
# Out:
# <Axes: >

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
marvel_df['first_appearance'].plot(kind='hist', bins=10, figsize=(8, 5))
plt.show()

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 11.,  1.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
